# %%
# Libraries used in this Machine Learning Project are pandas,numpy,matplotlib,dtale,klib,joblib,scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train=pd.read_csv(r'D:\Samarth\BigMart Sales Prediction\DataSet\train.csv')
df_test=pd.read_csv(r'D:\Samarth\BigMart Sales Prediction\DataSet\test.csv')

# %%
#to display training data
df_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#head() displays first 5 data of the dataset
df_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#to display test data : 
df_test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
#count number of rows and columns
df_train.shape
# Out:
# (8523, 12)

# %%
df_test.shape
# Out:
# (5681, 11)

# %%
#checking whether there are null values or not int the data set
df_train.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df_test.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False         True             False            False
# ...               ...          ...               ...              ...
# 5676            False        False             False            False
# 5677            False        False             False            False
# 5678            False        False             False            False
# 5679            False        False             False            False
# 5680            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
# to check data types of the dataset to fill missing or null values 
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
#calculate stastical analysis of numerical column to fill mean in place of null values in Item_Weight
df_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df_test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
df_train['Item_Weight'].fillna(df_train['Item_Weight'].mean(),inplace=True)
df_test['Item_Weight'].fillna(df_test['Item_Weight'].mean(),inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df_train['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
#check the index of Medium to insert in place of NaN
df_train['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df_test['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
# As we have maximum medium so we fill the null values of the categorical column with 'Medium' value
df_train['Outlet_Size'].fillna(df_train['Outlet_Size'].mode()[0],inplace=True)
df_test['Outlet_Size'].fillna(df_test['Outlet_Size'].mode()[0],inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
df_train.hist(figsize=(15,15))
plt.show()

# %% [markdown]
# # Selecting Features according to Requirements

# %%
# axis=0 is for rows and axis=1 is for columns
df_train.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)
df_test.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)

# %%
df_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
df_test
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0       20.750000          Low Fat         0.007565         Snack Foods
# 1        8.300000              reg         0.038428               Dairy
# 2       14.600000          Low Fat         0.099575              Others
# 3        7.315000          Low Fat         0.015388         Snack Foods
# 4       12.695633          Regular         0.118599               Dairy
# ...           ...              ...              ...                 ...
# 5676    10.500000          Regular         0.013496         Snack Foods
# 5677     7.600000          Regular         0.142991       Starchy Foods
# 5678    10.000000          Low Fat         0.073529  Health and Hygiene
# 5679    15.300000          Regular         0.000000              Canned
# 5680     9.500000          Regular         0.104720              Canned
#
#       Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# ...

# %% [markdown]
# # Perform Exploratory Data Analysis (EDA) Using dtale library

# %%
import dtale

# %%
dtale.show(df_train)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP01:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # EDA Using Pandas_Profiling

# %%
from pandas_profiling import ProfileReport
# Out:
# 2022-08-26 21:30:15,436 - INFO     - Pandas backend loaded 1.4.2
# 2022-08-26 21:30:15,460 - INFO     - Numpy backend loaded 1.21.5
# 2022-08-26 21:30:15,462 - INFO     - Pyspark backend NOT loaded
# 2022-08-26 21:30:15,465 - INFO     - Python backend loaded

# %%
profile=ProfileReport(df_train,title='Pandas Profiling Report')

# %%
# displaying detailed profile of the train dataset
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-08-26 16:00:28.414599&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # EDA Using Seaborn library

# %%
# %matplotlib is a line oriented magic-function which is used to display the output of plotting commands inline within frontends
import seaborn as sns
# %matplotlib inline

# %%
# we use annot to display percentage of each correlations
plt.figure(figsize=(10,5))
sns.heatmap(df_train.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df_test.corr(),annot=True)
plt.show()

# %% [markdown]
# # EDA Using klib library

# %%
import klib

# %%
klib.cat_plot(df_train)
# Out:
# GridSpec(6, 5)

# %%
klib.cat_plot(df_test)
# Out:
# GridSpec(6, 5)

# %%
klib.corr_mat(df_train)
# Out:
# <style type="text/css">
# #T_4b5ab_row0_col0, #T_4b5ab_row0_col2, #T_4b5ab_row0_col4, #T_4b5ab_row1_col1, #T_4b5ab_row2_col0, #T_4b5ab_row2_col2, #T_4b5ab_row2_col3, #T_4b5ab_row2_col4, #T_4b5ab_row3_col2, #T_4b5ab_row3_col3, #T_4b5ab_row4_col0, #T_4b5ab_row4_col2, #T_4b5ab_row4_col4 {
#   color: None;
# }
# #T_4b5ab_row0_col1, #T_4b5ab_row0_col3, #T_4b5ab_row1_col0, #T_4b5ab_row1_col2, #T_4b5ab_row1_col3, #T_4b5ab_row1_col4, #T_4b5ab_row2_col1, #T_4b5ab_row3_col0, #T_4b5ab_row3_col1, #T_4b5ab_row3_col4, #T_4b5ab_row4_col1, #T_4b5ab_row4_col3 {
#   color: #FF3344;
# }
# </style>
# <table id="T_4b5ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b5ab_level0_col0" class="col_heading level0 col0" >Item_Weight</th>
#       <th id="T_4b5ab_level0_col1" class="col_heading level0 col1" >Item_Visibility</th>
#       <th id="T_4b5ab_level0_col2" class="col_heading level0 col2" >Item_MRP</th>
# ...

# %%
klib.corr_mat(df_test)
# Out:
# <style type="text/css">
# #T_1f19a_row0_col0, #T_1f19a_row0_col2, #T_1f19a_row0_col3, #T_1f19a_row1_col1, #T_1f19a_row2_col0, #T_1f19a_row2_col2, #T_1f19a_row3_col0, #T_1f19a_row3_col3 {
#   color: None;
# }
# #T_1f19a_row0_col1, #T_1f19a_row1_col0, #T_1f19a_row1_col2, #T_1f19a_row1_col3, #T_1f19a_row2_col1, #T_1f19a_row2_col3, #T_1f19a_row3_col1, #T_1f19a_row3_col2 {
#   color: #FF3344;
# }
# </style>
# <table id="T_1f19a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f19a_level0_col0" class="col_heading level0 col0" >Item_Weight</th>
#       <th id="T_1f19a_level0_col1" class="col_heading level0 col1" >Item_Visibility</th>
#       <th id="T_1f19a_level0_col2" class="col_heading level0 col2" >Item_MRP</th>
#       <th id="T_1f19a_level0_col3" class="col_heading level0 col3" >Outlet_Establishment_Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f19a_level0_row0" class="row_heading level0 row0" >Item_Weight</th>
# ...

# %%
klib.corr_plot(df_train)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df_train)
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
klib.dist_plot(df_test)
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Density'>

# %%
#for checking missing values in the dataset using klib library
klib.missingval_plot(df_train)
# Out:
# No missing values found in the dataset.

# %%
klib.missingval_plot(df_train)
# Out:
# No missing values found in the dataset.

# %% [markdown]
# # Data Cleaning Using Klib library

# %%
# klib.data_cleaning(df_train) it performs data cleaning by dropping duplicate & empty rows/cols,adjust dataTypes
klib.data_cleaning(df_train)
# Out:
# Shape of cleaned data: (8523, 10)Remaining NAs: 0
#
# Changes:
# Dropped rows: 0
#      of which 0 duplicates. (Rows: [])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.43 MB (-66.15%)
#       item_weight item_fat_content  item_visibility              item_type  \
# 0             9.3          Low Fat         0.016047                  Dairy
# 1            5.92          Regular         0.019278            Soft Drinks
# 2            17.5          Low Fat          0.01676                   Meat
# 3       19.200001          Regular              0.0  Fruits and Vegetables
# 4            8.93          Low Fat              0.0              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519         8.38          Regular         0.046982           Baking Goods
# ...

# %%
klib.data_cleaning(df_test)
# Out:
# Shape of cleaned data: (5681, 9)Remaining NAs: 0
#
# Changes:
# Dropped rows: 0
#      of which 0 duplicates. (Rows: [])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.27 MB (-69.23%)
#       item_weight item_fat_content  item_visibility           item_type  \
# 0           20.75          Low Fat         0.007565         Snack Foods
# 1             8.3              reg         0.038428               Dairy
# 2            14.6          Low Fat         0.099575              Others
# 3           7.315          Low Fat         0.015388         Snack Foods
# 4       12.695633          Regular         0.118599               Dairy
# ...           ...              ...              ...                 ...
# 5676         10.5          Regular         0.013496         Snack Foods
# 5677          7.6          Regular         0.142991       Starchy Foods
# ...

# %%
klib.clean_column_names(df_train)
#also called inside data_cleaning()
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
klib.clean_column_names(df_test)
# Out:
#       item_weight item_fat_content  item_visibility           item_type  \
# 0       20.750000          Low Fat         0.007565         Snack Foods
# 1        8.300000              reg         0.038428               Dairy
# 2       14.600000          Low Fat         0.099575              Others
# 3        7.315000          Low Fat         0.015388         Snack Foods
# 4       12.695633          Regular         0.118599               Dairy
# ...           ...              ...              ...                 ...
# 5676    10.500000          Regular         0.013496         Snack Foods
# 5677     7.600000          Regular         0.142991       Starchy Foods
# 5678    10.000000          Low Fat         0.073529  Health and Hygiene
# 5679    15.300000          Regular         0.000000              Canned
# 5680     9.500000          Regular         0.104720              Canned
#
#       item_mrp  outlet_establishment_year outlet_size outlet_location_type  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                8523 non-null   float64
#  1   item_fat_content           8523 non-null   object
#  2   item_visibility            8523 non-null   float64
#  3   item_type                  8523 non-null   object
#  4   item_mrp                   8523 non-null   float64
#  5   outlet_establishment_year  8523 non-null   int64
#  6   outlet_size                8523 non-null   object
#  7   outlet_location_type       8523 non-null   object
#  8   outlet_type                8523 non-null   object
#  9   item_outlet_sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 666.0+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                5681 non-null   float64
#  1   item_fat_content           5681 non-null   object
#  2   item_visibility            5681 non-null   float64
#  3   item_type                  5681 non-null   object
#  4   item_mrp                   5681 non-null   float64
#  5   outlet_establishment_year  5681 non-null   int64
#  6   outlet_size                5681 non-null   object
#  7   outlet_location_type       5681 non-null   object
#  8   outlet_type                5681 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 399.6+ KB

# %%
df_train=klib.convert_datatypes(df_train)
#used to convert existing data types to more efficient data types
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                8523 non-null   Float32
#  1   item_fat_content           8523 non-null   category
#  2   item_visibility            8523 non-null   Float32
#  3   item_type                  8523 non-null   category
#  4   item_mrp                   8523 non-null   Float32
#  5   outlet_establishment_year  8523 non-null   int16
#  6   outlet_size                8523 non-null   category
#  7   outlet_location_type       8523 non-null   category
#  8   outlet_type                8523 non-null   category
#  9   item_outlet_sales          8523 non-null   Float32
# dtypes: Float32(4), category(5), int16(1)
# memory usage: 226.2 KB

# %%
df_test=klib.convert_datatypes(df_test)
#used to convert existing data types to more efficient data types
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                5681 non-null   Float32
#  1   item_fat_content           5681 non-null   category
#  2   item_visibility            5681 non-null   Float32
#  3   item_type                  5681 non-null   category
#  4   item_mrp                   5681 non-null   Float32
#  5   outlet_establishment_year  5681 non-null   int16
#  6   outlet_size                5681 non-null   category
#  7   outlet_location_type       5681 non-null   category
#  8   outlet_type                5681 non-null   category
# dtypes: Float32(3), category(5), int16(1)
# memory usage: 123.5 KB

# %%
klib.mv_col_handling(df_train)
#used to drop features having high ratio of missiong values according to the given dataset
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0             9.3          Low Fat         0.016047                  Dairy
# 1            5.92          Regular         0.019278            Soft Drinks
# 2            17.5          Low Fat          0.01676                   Meat
# 3       19.200001          Regular              0.0  Fruits and Vegetables
# 4            8.93          Low Fat              0.0              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519         8.38          Regular         0.046982           Baking Goods
# 8520         10.6          Low Fat         0.035186     Health and Hygiene
# 8521         7.21          Regular         0.145221            Snack Foods
# 8522         14.8          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
klib.mv_col_handling(df_test)
# Out:
#       item_weight item_fat_content  item_visibility           item_type  \
# 0           20.75          Low Fat         0.007565         Snack Foods
# 1             8.3              reg         0.038428               Dairy
# 2            14.6          Low Fat         0.099575              Others
# 3           7.315          Low Fat         0.015388         Snack Foods
# 4       12.695633          Regular         0.118599               Dairy
# ...           ...              ...              ...                 ...
# 5676         10.5          Regular         0.013496         Snack Foods
# 5677          7.6          Regular         0.142991       Starchy Foods
# 5678         10.0          Low Fat         0.073529  Health and Hygiene
# 5679         15.3          Regular              0.0              Canned
# 5680          9.5          Regular          0.10472              Canned
#
#         item_mrp  outlet_establishment_year outlet_size outlet_location_type  \
# ...

# %% [markdown]
# # Preprocessing before Model Building

# %% [markdown]
#  ## 1) Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df_train['item_fat_content'] = le.fit_transform(df_train['item_fat_content'])
df_train['item_type'] = le.fit_transform(df_train['item_type'])
df_train['outlet_size'] = le.fit_transform(df_train['outlet_size'])
df_train['outlet_type'] = le.fit_transform(df_train['outlet_type'])
#to put numerical values instead of strings, so that model can understand it

# %%
df_train
# Out:
#       item_weight  item_fat_content  item_visibility  item_type    item_mrp  \
# 0             9.3                 1         0.016047          4  249.809204
# 1            5.92                 2         0.019278         14   48.269199
# 2            17.5                 1          0.01676         10  141.617996
# 3       19.200001                 2              0.0          6  182.095001
# 4            8.93                 1              0.0          9   53.861401
# ...           ...               ...              ...        ...         ...
# 8518        6.865                 1         0.056783         13  214.521805
# 8519         8.38                 2         0.046982          0  108.156998
# 8520         10.6                 1         0.035186          8   85.122398
# 8521         7.21                 2         0.145221         13  103.133202
# 8522         14.8                 1         0.044878         14   75.467003
#
# ...

# %%
df_test['item_fat_content'] = le.fit_transform(df_test['item_fat_content'])
df_test['item_type'] = le.fit_transform(df_test['item_type'])
df_test['outlet_size'] = le.fit_transform(df_test['outlet_size'])
df_test['outlet_type'] = le.fit_transform(df_test['outlet_type'])

# %%
df_test
# Out:
#       item_weight  item_fat_content  item_visibility  item_type    item_mrp  \
# 0           20.75                 1         0.007565         13  107.862198
# 1             8.3                 4         0.038428          4   87.319801
# 2            14.6                 1         0.099575         11  241.753799
# 3           7.315                 1         0.015388         13  155.033997
# 4       12.695633                 2         0.118599          4  234.229996
# ...           ...               ...              ...        ...         ...
# 5676         10.5                 2         0.013496         13  141.315399
# 5677          7.6                 2         0.142991         15  169.144806
# 5678         10.0                 1         0.073529          8  118.744003
# 5679         15.3                 2              0.0          3  214.621796
# 5680          9.5                 2          0.10472          3   79.795998
#
# ...

# %% [markdown]
# ## 2) One Hot Encoding : for better Accuracy

# %%
df_train = pd.get_dummies(df_train,columns=['outlet_size','outlet_location_type','item_fat_content','outlet_type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [110], in <cell line: 1>()
# ----> 1 df_train = pd.get_dummies(df_train,columns=['outlet_size','outlet_location_type','item_fat_content','outlet_type'])
#
# File D:\Samarth\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:931, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     929     raise TypeError("Input must be a list-like for parameter `columns`")
#     930 else:
# --> 931     data_to_encode = data[columns]
#     933 # validate prefixes and separator to avoid silently dropping cols
#     934 def check_len(item, name):
#
# File D:\Samarth\Anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# ...

# %%
df_train
# Out:
#       item_weight  item_visibility  item_type  item_mrp  \
# 0             284              664          4      5592
# 1              57              880         14       473
# 2             376              715         10      2901
# 3             393                0          6      4227
# 4             265                0          9       627
# ...           ...              ...        ...       ...
# 8518          125             3912         13      4955
# 8519          233             3278          0      2023
# 8520          299             2302          8      1263
# 8521          149             7174         13      1857
# 8522          347             3108         14      1011
#
#       outlet_establishment_year  item_outlet_sales  outlet_size_0  \
# 0                             4               2540              0
# 1                             8                422              0
# 2                             4               1639              0
# ...

# %%
df_test = pd.get_dummies(df_test,columns=['outlet_size','outlet_location_type','item_fat_content','outlet_type'])

# %%
df_test
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0             404                 1               66         13      1460
# 1             223                 4             1714          4       965
# 2             338                 1             4041         11      4076
# 3             156                 1              388         13      2522
# 4             319                 2             4422          4      3972
# ...           ...               ...              ...        ...       ...
# 5676          293                 2              290         13      2164
# 5677          178                 2             4814         15      2833
# 5678          288                 1             3255          8      1752
# 5679          349                 2                0          3      3691
# 5680          283                 2             4163          3       806
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# ...

# %% [markdown]
# # 3) Splitting Training dataset into train and test

# %%
X=df_train.drop('item_outlet_sales',axis=1)

# %%
X
# Out:
#       item_weight  item_fat_content  item_visibility  item_type    item_mrp  \
# 0             9.3                 1         0.016047          4  249.809204
# 1            5.92                 2         0.019278         14   48.269199
# 2            17.5                 1          0.01676         10  141.617996
# 3       19.200001                 2              0.0          6  182.095001
# 4            8.93                 1              0.0          9   53.861401
# ...           ...               ...              ...        ...         ...
# 8518        6.865                 1         0.056783         13  214.521805
# 8519         8.38                 2         0.046982          0  108.156998
# 8520         10.6                 1         0.035186          8   85.122398
# 8521         7.21                 2         0.145221         13  103.133202
# 8522         14.8                 1         0.044878         14   75.467003
#
# ...

# %%
Y=df_train['item_outlet_sales']

# %%
Y
# Out:
# 0       3735.137939
# 1        443.422791
# 2        2097.27002
# 3        732.380005
# 4          994.7052
#            ...
# 8518    2778.383301
# 8519     549.284973
# 8520    1193.113647
# 8521    1845.597656
# 8522     765.669983
# Name: item_outlet_sales, Length: 8523, dtype: Float32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=101, test_size=0.2)

# %%
X_train
# Out:
#       item_weight  item_fat_content  item_visibility  item_type    item_mrp  \
# 3684        19.25                 1         0.101689          4   54.695599
# 1935         7.63                 1          0.06141         14     94.6436
# 5142        19.35                 2         0.065891         10  167.081604
# 4978         6.38                 0         0.031898          4  177.434402
# 2299    16.700001                 1          0.02211          4  110.888603
# ...           ...               ...              ...        ...         ...
# 599           5.0                 1         0.044005         14  188.852997
# 5695        14.65                 1         0.170664          7   56.461399
# 8006         12.5                 1         0.018849          8   96.738403
# 1361        9.695                 2         0.129009          0  226.940399
# 1547         15.7                 1         0.161317          9   57.556198
#
# ...

# %%
X_test
# Out:
#       item_weight  item_fat_content  item_visibility  item_type    item_mrp  \
# 8179         11.0                 1         0.055163          8    100.3358
# 8355         18.0                 1         0.038979         13    148.6418
# 3411         7.72                 2         0.074731          1   77.598602
# 7089    20.700001                 1         0.049035          6     39.9506
# 6954         7.55                 1         0.027225          3  152.934006
# ...           ...               ...              ...        ...         ...
# 1317        16.75                 1         0.105019         13     155.263
# 4996         8.52                 1         0.027059         14  153.368195
# 531          15.6                 1         0.111686         11  184.792404
# 3891         17.1                 1              0.0          9  114.685997
# 6629         6.26                 2         0.009888         10  150.736603
#
# ...

# %%
Y_train
# Out:
# 3684     163.786804
# 1935    1607.241211
# 5142    1510.034424
# 4978    1784.343994
# 2299    3558.035156
#            ...
# 599     5502.836914
# 5695    1436.796387
# 8006    2167.844727
# 1361    2700.484863
# 1547     829.586792
# Name: item_outlet_sales, Length: 6818, dtype: Float32

# %%
Y_test
# Out:
# 8179     904.822205
# 8355    2795.694092
# 3411    1947.464966
# 7089      872.86377
# 6954    2450.144043
#            ...
# 1317    1721.093018
# 4996     914.809204
# 531      370.184814
# 3891    1358.232056
# 6629    2418.185547
# Name: item_outlet_sales, Length: 1705, dtype: Float32

# %% [markdown]
# # 4) Standarization Or Normalization

# %%
X.describe()
# Out:
#        item_weight  item_fat_content  item_visibility    item_type  \
# count  8523.000000       8523.000000      8523.000000  8523.000000
# mean     12.857646          1.369354         0.066132     7.226681
# std       4.226124          0.644810         0.051598     4.209990
# min       4.555000          0.000000         0.000000     0.000000
# 25%       9.310000          1.000000         0.026989     4.000000
# 50%      12.857645          1.000000         0.053931     6.000000
# 75%      16.000000          2.000000         0.094585    10.000000
# max      21.350000          4.000000         0.328391    15.000000
#
#           item_mrp  outlet_establishment_year  outlet_size  outlet_type
# count  8523.000000                8523.000000  8523.000000  8523.000000
# mean    140.992770                1997.831867     1.170832     1.201220
# std      62.275066                   8.371760     0.600327     0.796459
# min      31.290001                1985.000000     0.000000     0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()

# %%
X_train_std = s.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [104], in <cell line: 1>()
# ----> 1 X_train_std=s.fit_transform(X_train)
#
# File D:\conda\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# File D:\conda\lib\site-packages\sklearn\preprocessing\_data.py:806, in StandardScaler.fit(self, X, y, sample_weight)
#     804 # Reset internal state before fitting
#     805 self._reset()
# ...

# %%
X_train_std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [109], in <cell line: 1>()
# ----> 1 X_train_std
#
# NameError: name 'X_train_std' is not defined

# %%
# we don't apply fit here because fit is used for learning
X_test_std = sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [110], in <cell line: 2>()
#       1 # we don't apply fit here because fit is used for learning
# ----> 2 X_test_std = sc.transform(X_test)
#
# File D:\Samarth\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:973, in StandardScaler.transform(self, X, copy)
#     970 check_is_fitted(self)
#     972 copy = copy if copy is not None else self.copy
# --> 973 X = self._validate_data(
#     974     X,
#     975     reset=False,
#     976     accept_sparse="csr",
#     977     copy=copy,
#     978     estimator=self,
#     979     dtype=FLOAT_DTYPES,
#     980     force_all_finite="allow-nan",
#     981 )
#     983 if sparse.issparse(X):
#     984     if self.with_mean:
#
# ...

# %%
X_test_std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
# ----> 1 X_test_std
#
# NameError: name 'X_test_std' is not defined

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LinearRegression()

# %%
X_test.head()
# Out:
#       item_weight  item_visibility  item_type  item_mrp  \
# 2042          243             5628          9      2186
# 4013          326             3510          3      3229
# 2723          326             7392          3      4337
# 4355          291             1489         13      5007
# 5442          114             6608          0       326
#
#       outlet_establishment_year  outlet_size_0  outlet_size_1  outlet_size_2  \
# 2042                          8              0              1              0
# 4013                          0              0              1              0
# 2723                          0              0              1              0
# 4355                          6              0              0              1
# 5442                          6              0              0              1
#
#       outlet_location_type_0  outlet_location_type_1  outlet_location_type_2  \
# 2042                       0                       0                       1
# ...

# %%
Y_pred_lr = lr.predict(X_test_std)

# %%
Y_pred_lr
# Out:
# array([1219.17489541, 2375.65179658, 2703.94777149, ..., 1310.62082681,
#        2047.46728185, 1800.8263162 ])

# %%
Y_test
# Out:
# 2042    2224
# 4013    2961
# 2723    3226
# 4355    2769
# 5442     513
#         ...
# 5455     856
# 4947     290
# 7263     833
# 4401    2623
# 4935    1929
# Name: item_outlet_sales, Length: 1705, dtype: int64

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print(r2_score(Y_test,Y_pred_lr))
print(mean_absolute_error(Y_test,Y_pred_lr))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_lr)))
# Out:
# 0.6489462346951301
# 433.7773864115924
# 543.5650047149375

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
Y_pred_rf = rf.predict(X_test)

# %%
X_test
# Out:
#       item_weight  item_visibility  item_type  item_mrp  \
# 2042          243             5628          9      2186
# 4013          326             3510          3      3229
# 2723          326             7392          3      4337
# 4355          291             1489         13      5007
# 5442          114             6608          0       326
# ...           ...              ...        ...       ...
# 5455          284             4883          9      5531
# 4947          358             7390          9       789
# 7263          382             1168          6      1616
# 4401          326             1299          8      2232
# 4935          408             2672          9      3289
#
#       outlet_establishment_year  outlet_size_0  outlet_size_1  outlet_size_2  \
# 2042                          8              0              1              0
# 4013                          0              0              1              0
# ...

# %%
Y_pred_rf
# Out:
# array([1383.97, 2602.4 , 2853.61, ..., 1367.38, 1658.17, 1735.61])

# %%
Y_test
# Out:
# 2042    2224
# 4013    2961
# 2723    3226
# 4355    2769
# 5442     513
#         ...
# 5455     856
# 4947     290
# 7263     833
# 4401    2623
# 4935    1929
# Name: item_outlet_sales, Length: 1705, dtype: int64

# %%
print(r2_score(Y_test,Y_pred_rf))
print(mean_absolute_error(Y_test,Y_pred_rf))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_rf)))
# Out:
# 0.6429897864429839
# 417.9459472140762
# 548.1570338762746

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

model = RandomForestRegressor()

n_estimators = [10,100,1000]

max_depth = range(1,31)

min_samples_leaf = np.linspace(0.1,1.0)

max_features = ['auto','log2','sqrt']

min_samples_split = np.linspace(0.1,1.0,10)

grid = dict(n_estimators=n_estimators,max_depth=max_depth)

grid_search_forest = GridSearchCV(estimator=model,param_grid=grid,n_jobs=-1,scoring='r2',error_score=0,verbose=2,cv=2)

grid_search_forest.fit(X_train_std,Y_train) 

print(f"Best: {grid_search_forest.best_score_:.3f} using {grid_search_forest.best_params_}")
means = grid_search_forest.cv_results_['mean_test_score']
stds = grid_search_forest.cv_results_['std_test_score']
params = grid_search_forest.cv_results_['params']

for mean,stdev,param in zip(means,stds,params):
    print(f"{mean : .3f} ({stdev:.3f}) with : {param}")
# Out:
# Fitting 2 folds for each of 90 candidates, totalling 180 fits
# Best: 0.654 using {'max_depth': 5, 'n_estimators': 1000}
#  0.329 (0.029) with : {'max_depth': 1, 'n_estimators': 10}
#  0.354 (0.023) with : {'max_depth': 1, 'n_estimators': 100}
#  0.346 (0.031) with : {'max_depth': 1, 'n_estimators': 1000}
#  0.534 (0.000) with : {'max_depth': 2, 'n_estimators': 10}
#  0.536 (0.006) with : {'max_depth': 2, 'n_estimators': 100}
#  0.535 (0.005) with : {'max_depth': 2, 'n_estimators': 1000}
#  0.612 (0.010) with : {'max_depth': 3, 'n_estimators': 10}
#  0.611 (0.010) with : {'max_depth': 3, 'n_estimators': 100}
#  0.613 (0.009) with : {'max_depth': 3, 'n_estimators': 1000}
#  0.647 (0.001) with : {'max_depth': 4, 'n_estimators': 10}
#  0.648 (0.001) with : {'max_depth': 4, 'n_estimators': 100}
#  0.649 (0.002) with : {'max_depth': 4, 'n_estimators': 1000}
#  0.653 (0.001) with : {'max_depth': 5, 'n_estimators': 10}
#  0.654 (0.001) with : {'max_depth': 5, 'n_estimators': 100}
# ...

# %%
Y_pred_sf_grid=grid_search_forest.predict(X_test_std)

# %%
r2_score(Y_test,Y_pred_sf_grid)
# Out:
# 0.6720177450080893

# %% [markdown]
# # Saving the Model

# %%
import joblib

# %%
joblib.dump(grid_search_forest,r'D:\Samarth\BigMart Sales Prediction\Model\random_forest_grid.sav')
# Out:
# ['D:\\Samarth\\BigMart Sales Prediction\\Model\\random_forest_grid.sav']

# %%
model = joblib.load(r'D:\Samarth\BigMart Sales Prediction\Model\random_forest_grid.sav')

# %%
model.predict(X_test_std)
# Out:
# array([1393.58839618, 2509.97827956, 2853.59768481, ..., 1232.13991729,
#        1976.12726168, 1791.16316872])
